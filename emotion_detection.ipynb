# %%
import pandas as pd
df=pd.read_csv('/content/emotion_words.csv')

# %%
df.columns
# Out:
# Index(['emotion', 'word', 'odds', 'freq'], dtype='object')

# %%
df=df.drop(columns=['odds'])

# %%
df=df.drop(columns=['freq'])

# %%
df['emotion'].unique()
for i in df['emotion'].unique():
  if i=='love' or i=='anger':
    continue
  df = df[df['emotion'] != i]
# (df['emotion']=='love').shape

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['emotion']=le.fit_transform(df['emotion'])

# %%
df
# Out:
#      emotion      word
# 193        0      fuck
# 194        0      hate
# 195        0   fucking
# 196        0     angry
# 197        0      dare
# ..       ...       ...
# 848        1     scott
# 849        1  delivers
# 850        1     mocks
# 851        1     sweet
# 852        1      much
#
# [92 rows x 2 columns]

# %%
df['emotion'].unique()
# Out:
# array([0, 1])

# %%
df
# Out:
#      emotion      word
# 193        0      fuck
# 194        0      hate
# 195        0   fucking
# 196        0     angry
# 197        0      dare
# ..       ...       ...
# 848        1     scott
# 849        1  delivers
# 850        1     mocks
# 851        1     sweet
# 852        1      much
#
# [92 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidfv=TfidfVectorizer(ngram_range=(1, 2))

# %%
from sklearn.model_selection import train_test_split
x=df['word']
y=df['emotion']
x_train,x_test,y_train,y_test=train_test_split(x,y)
y
# Out:
# 193    0
# 194    0
# 195    0
# 196    0
# 197    0
#       ..
# 848    1
# 849    1
# 850    1
# 851    1
# 852    1
# Name: emotion, Length: 92, dtype: int64

# %%
x_train_features=tfidfv.fit_transform(x_train)
x_test_features=tfidfv.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.svm import SVC

# %%
lr=LogisticRegression()
# dc=DecisionTreeClassifier()
# sv=SVC()
lr.fit(x_train_features,y_train)
# dc.fit(x_train_features,y_train)
# sv.fit(x_train_features,y_train)
# Out:
# LogisticRegression()

# %%
m=lr.predict(x_train_features)
# m=dc.predict(x_train_features)
# m=sv.predict(x_train_features)

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(m,y_train)*100)
# Out:
# 100.0

# %%
k=lr.predict(x_test_features)
# k=dc.predict(x_test_features)
# k=sv.predict(x_test_features)

# %%
print(accuracy_score(k,y_test)*100)
# Out:
# 73.91304347826086

# %%
m=['delivers']
p=tfidfv.transform(m)
sv.predict(p)
# Out:
# array([1])
